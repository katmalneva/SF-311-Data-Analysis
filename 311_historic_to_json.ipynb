# %%
import pandas as pd
import numpy as np
import json

# %%
historic_311 = pd.read_csv('../311_Cases_historic.csv')

# %%
historic_311.head()
# Out:
#      CaseID                  Opened                  Closed  \
# 0  13437452  02/01/2021 07:48:00 AM  02/02/2021 09:25:00 AM
# 1   9657146  10/11/2018 09:51:00 AM  10/11/2018 10:59:00 AM
# 2  13461310  02/06/2021 03:55:00 PM  02/06/2021 07:38:53 PM
# 3  13465537  02/08/2021 08:06:00 AM  02/09/2021 10:37:00 AM
# 4  13475791  02/10/2021 11:26:00 AM  02/12/2021 09:10:24 AM
#
#                   Updated  Status                     Status Notes  \
# 0  02/02/2021 09:25:00 AM  Closed                    Case Resolved
# 1  10/11/2018 10:59:00 AM  Closed                    Case Resolved
# 2  02/06/2021 07:38:53 PM  Closed        Case Resolved - Completed
# 3  02/09/2021 10:37:00 AM  Closed                    Case Resolved
# 4  02/12/2021 09:10:24 AM  Closed  Case Resolved - WASTE NOT FOUND
#
#    Responsible Agency                      Category           Request Type  \
# 0       DPW Ops Queue  Street and Sidewalk Cleaning       General Cleaning
# ...

# %%
historic_311.to_json('../311_Historic_02052026.json', orient='records')

# %%
historic_dict = historic_311.to_json(orient='records')

# %%
historic_dict[:50]
# Out:
# '[{"CaseID":13437452,"Opened":"02\\/01\\/2021 07:48:0'
